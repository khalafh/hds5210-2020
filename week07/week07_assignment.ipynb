# %% [markdown]
# # Week 7 Assignment
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  Answer the questions below as instructed.

# %% [markdown]
# ### 31.1 Finding files on the internet
#
# Go to healthdata.gov and find a file that looks interesting to you.  Provide the metadata below that describes the file you located.
#
# The cell below is a "markdown" cell.  Just double-click it to edit the contents and then Shift-Enter to show the content as formatted text.
#
# ---

# %% [markdown]
# **File Name:**  Onsite Soil Evaluators List
#
# **URL to Page:** https://data.mo.gov/d/4xqz-ug2j
#
# **Description:** This data includes names of soil evaluators, and some other information about there job and dates. it seems interesting because it is related to my major (civil engineering)
#
# **URL to Actual File:** https://data.mo.gov/api/views/4xqz-ug2j/rows.csv
#
# **File Format:** CSV

# %% [markdown]
# ---

# %% [markdown]
# ### 31.2 Use Pandas to load data from internet
#
# Now write a block of code (doesn't need to be in a function) that will load the file using Pandas and describe the shape of the file contents.  I've provided a cell with some comments in it to help get you started.
#
# Pandas documentation for loading data https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#input-output
#
# Pandas documentation for describing the shape of data https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.shape.html

# %%
import pandas as pd

# Load data using one of the read functions depending on your data file type
# data = pd.read_ ...

data = pd.read_csv ("https://data.mo.gov/api/views/4xqz-ug2j/rows.csv")
# Print out the row / column count
# data. ...
data.shape
# Out:
# (51, 8)

# %%
pd.read_csv ("https://data.mo.gov/api/views/4xqz-ug2j/rows.csv")
# Out:
#        Last Name          First Name   MI Date of Expiration  \
# 0        Atkison                  L.   J.         05/31/2020
# 1         Bettes             Melissa    S         03/31/2020
# 2     Carmichael                Doug  NaN         03/31/2020
# 3      Nothstine               Chris    E         09/30/2022
# 4       Fletcher                Mike  NaN         03/31/2020
# 5         Massie                Matt    D         03/31/2020
# 6         Gaines             Douglas    B         03/31/2020
# 7          Clark               Kerry    M         04/30/2022
# 8         Dohmen                Tony    E         03/31/2020
# 9        Richner              Jordan    M         06/30/2020
# 10     Henderson             Richard    L         03/31/2020
# 11        Barnes                Paul    E         08/31/2022
# 12        Blaine                 Joe    E         03/31/2020
# 13     Henderson  Christian (Jordan)    J         11/30/2021
# 14        Mayhan               Bryan    D         11/30/2021
# 15          Doll              Travis    A         06/30/2021
# 16      Klaproth                 Dan    E         03/31/2020
# 17        Bowers             Michael    J         08/31/2020
# 18       Chorice                  RD  NaN         03/31/2020
# 19         Miles               Randy    J         03/31/2020
# 20         Bauer                John    H         10/31/2022
# 21        Kelley                 Wyn    A         03/31/2020
# 22      Kluender                 Bob    W         03/31/2020
# 23        Purdom             Richard    K         03/31/2020
# 24        DeWitt            Benjamin    A         11/30/2020
# 25          Dyer                Clay  NaN         01/31/2020
# 26         Owens              Daniel    L         04/30/2022
# 27       Harwood             Charles    M         03/31/2020
# 28       Chapman               Chris    L         04/30/2020
# 29        Taylor                 Tom    W         03/31/2020
# 30          Bond             William    H         03/31/2020
# 31         McKee                Brad    D         07/31/2022
# 32          Bean       Gregory (Mac)   M.         05/30/2022
# 33  Knoernschild             Timothy    O         03/31/2020
# 34        Stiens               Chris    R         03/31/2020
# 35        DeWitt                 Tom    A         04/30/2022
# 36        Wegman               Scott    W         03/31/2020
# 37          Deem              Rachel  NaN         03/31/2020
# 38           Ivy                Gary    D         05/31/2020
# 39      Chalfant             Michael    L         03/31/2020
# 40        Osborn                Mark    W         11/30/2020
# 4   31720 S. 602 Rd.\nGrove, OK 74344\n(36.557144,...
# 5   16718 Lawrence 1100\nMt. Vernon, MO 65712\n(37...
# 6   8611 Wiseman RD\nWorden, IL 62097\n(38.958632,...
# 7   8518 County Road 379\nNew Bloomfield, MO 65063...
# 8   1416 Herron Dr\nJefferson City, MO 65101\n(38....
# 9   1615 E. 530th Road\nBrighton, MO 65617\n(37.47...
# 10  3426 S 240th Rd\nLouisburg, MO 65685\n(37.7556...
# 11                2898 SW 233rd\nPlattsburg, MO 64477
# 12  986 Crosstie Rd\nSeymour, MO 65746\n(37.122131...
# 13  9 Freedom Road\nUrbana, MO 65767\n(37.793213, ...
# 14  1311 Robert Ray Dr\nColumbia, MO 65202\n(38.96...
# 15  1505 E. High Street\nJefferson City, MO 65101\...
# 16  2218 County Rd 318\nJackson, MO 63755\n(37.345...
# 17  12504 W FR 168\nRepublic, MO 65738\n(37.145328...
# 18  4303 S. Troy Ave.\nSpringfield, MO 65810\n(37....
# 19       6500 Gillespie Bridge Rd\nColumbia, MO 65203
# 20  4077 N. Saint Peters Pkway, Suite 110\nSt Pete...
# 21  6611 Sunrise Acres\nJefferson City, MO 65101\n...
# 22  295 Southtown Ln\nPerryville, MO 63775\n(37.70...
# 23  3810 S 201 Rd\nEl Dorado Springs, MO 64744\n(3...
# 24  7439 E. Tara Lane\nRogersville, MO 65742\n(37....
# 25  13803 County Rd CC\nHolt, MO 64048\n(39.44834,...
# 26                      PO Box 631\nRaymore, MO 64083
# 27               PO Box 176\nJefferson City, MO 65102
# 28                     PO Box 73\nSt. Clair, MO 63077
# 29  913 N Main\nNevada, MO 64772\n(37.846526, -94....
# 30  7619 State Route C\nSte Genevieve, MO 63670\n(...
# 31  5791 State Rt. AP\nWillow Springs, MO 65793\n(...
# 32  2412 Kays Pointe Drive\nColumbia, MO 65201\n(3...
# 33  870 SE HWY 7\nClinton, MO 64735\n(38.318356, -...
# 34  24301 Neon Rd.\nRavenwood, MO 64479\n(40.37038...
# 35  5578 East Farm Road 186\nRogersville, MO 65742...
# 36  7030 County Road 308\nTaylor, MO 63471\n(39.93...
# 37  28480 Juniper RD\nCarl Junction, MO 64834\n(37...
# 38  665 Front St PO Box 105\nHolt, MO 64048\n(39.4...
# 39  4660 County Rd 414\nFulton, MO 65251\n(38.7843...
# 40  609 Hardin St\nColumbia, MO 65203\n(38.960983,...
# 41  835 Gerling Lane\nNew Haven, MO 63068\n(38.577...
# 42                RT3 Box 3630\nMarble Hill, MO 63764
# 43  909 S. Greenwood Avenue\nColumbia, MO 65201\n(...
# 44                  RT 71 Box 12\nWeaubleau, MO 65774
# 45  410 E Bodine Ave\nClinton, MO 64735\n(38.36019...
# 46  13404 Hammer Rd\nNeosho, MO 64850\n(36.874656,...
# 47                  PO Box 617\nOsage Beach, MO 65065
# 48            6028 NW 95th St.\nKansas City, MO 64154
# 49  4077 N Saint Peters\nSt Peters, MO 63304\n(38....
# 50  2102 Pennsylvania Ave.\nJoplin, MO 64804\n(37....
#
#                                       Counties Served
# 0    Andrew, Buchanan, Clay, Clinton, Daviess, Platte
# 1   Barry, Lawrence, McDonald, Newton, Stone, Tane...
# 2   Barry, Christian, Dade, Greene, Lawrence, Newt...
# 3   Andrew, Buchanan, Clinton, Daviess, DeKalb, Ge...
# 4                            Jasper, McDonald, Newton
# 5                               Barry, Dade, Lawrence
# 6   Franklin, Jefferson, Lincoln, Montgomery, Pike...
# 7   Boone, Callaway, Cooper, Gasconade, Montgomery...
# 8   Boone, Callaway, Cole, Gasconade, Miller, Moni...
# 9                         Polk, Dade, Hickory, Dallas
# 10  Benton, Camden, Cedar, Christian, Dade, Dallas...
# 11  Andrew, Buchanan, Caldwell, Clay, Clinton, Car...
# 12                                 Christian, Webster
# 13  Dallas, Polk, Hickory,Laclede,Webster, Christi...
# 14  Boone,  Randolph,  Audrain,  Macon, Saline, Co...
# 15                      Cole, Callaway, Boone, Miller
# 16  Butler, Bollinger, Cape Girardeau, Carter, Dun...
# 17                                             Greene
# 18  Barry, Cedar, Chrisitan, Dade, Dallas, Greene,...
# 19  Audrain, Boone, Callaway, Clay, Cole, Cooper, ...
# 20  Franklin, Jefferson, Lincoln, St. Charles, Pik...
# 21  Audrain, Boone, Cole, Cooper, Gasconade, Howar...
# 22                              Cape Girardeau, Perry
# 23  Barry, Barton, Bates, Cedar, Dade, Dallas, Gre...
# 24                Greene, Christian, Webster, Douglas
# 25                                 Clay, Clinton, Ray
# 26  Cass, Platte, Jackson, Clay, Ray, Johnson, Bat...
# 27                                               Cole
# 28  St. Louis,  Franklin,  Crawford,  Washington, ...
# 29  Barton, Bates, Cedar, Cass, Dade, Henry, Jaspe...
# 30  Cape Girardeau, Franklin, Iron, Jefferson, Mad...
# 31  Howell, Douglas, Ozark, Oregon, Ripley, Shanno...
# 32                   Boone, Howard, Audrain, Callaway
# 33  Benton, Camden, Carroll, Chariton, Cooper, Hen...
# 34  Andrew, Atchison, Buchanan, Carroll, Clay, Cli...
# 35  Greene, Christian, Webster, Polk, Douglas, Oza...
# 36  Adair, Callaway, Clark, Chariton, Grundy, Knox...
# 37  Jasper, Newton, McDonald, Polk, Dade, Barry, L...
# 38                                 Clay, Clinton, Ray
# 39  Audrain, Boone, Callaway, Cole, Gasconade, Mon...
# 40         Audrain, Boone, Callaway, Howard, Randolph
# 41  Audrain, Callaway, Cole, Crawford, Dent, Frank...
# 42  Bollinger, Butler, Cape Girardeau, Carter, Dun...
# 43                    Boone, Howard, Moniteau, Cooper
# 44                                      Hickory, Polk
# 45                     Cass, Henry, Pettis, St. Clair
# 46   Barry, Newton, McDonald, Jasper, Lawrence, Stone
# 47  Audrain, Benton, Callawy, Camden, Cole, Cooper...
# 48  Andrew, Buchanan, Clay, Clinton, Lafayette, Ja...
# 49  Franklin, Jefferson, Lincoln, Montgomery, Pike...
# 50  Barry, Barton, Lawrence, McDonald, Newton, Jasper

# %% [markdown]
# ---

# %% [markdown]
# ### 32.1 HTML Basics
#
# HTML is a form of which othere data format we've talked about:
#
# > A) Binary
# >
# > B) eXtensible Markup Language
# >
# > C) JavaScript Object Notation
# >
# > D) HL7 FHIR

# %%
answer321 = "B"

# %% [markdown]
# ### 32.2 Things in HTML
#
# Which of the following is **not** a part of HTML:
#
# > A) element
# >
# > B) tag
# >
# > C) dictionary
# >
# > D) attribute

# %%
answer322 = "C"

# %% [markdown]
# ### 32.3 Parsing HTML in Python
#
# Which of the following packages can be used to extract a table of data from HTML using Python (include all that apply in a list):
#
# > A) lxml
# >
# > B) BeautifulSoup
# >
# > C) Pandas
# >
# > D) fuzzywuzzy

# %%
answer323 = ["B","C"]
